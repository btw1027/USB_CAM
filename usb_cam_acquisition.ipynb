# %%
import numpy
from matplotlib import pyplot as plt
import PySpin
from datetime import datetime
import os

# %%
def configure_custom_image_settings(cam,
    num_images,
    downsize_width,
    downsize_height,
    acquisition_frame_rate, 
    exposure_time_to_set,
    gain_to_set):
    """
    Configures the width and height of the image, the
    offset x and y, the acquisition frame rate, exposure, and gain. 

    :param cam: Camera to configure settings on.
    :param downsize_width: default=2, max width (5472) divided by downsize_width
    :param downsize_height: default=2, max height (3648) divided by downsize_height
    :param acquisition_frame_rate: default = 3 Hz, min 2.33, max depends on width/height capture size and connection speed
    :param exposure_time_to_set: default = 15000 microseconds
    :param gain_to_set: default = 6.29
    :type cam: CameraPtr
    :return: True if successful, False otherwise.
    :rtype: bool
    """
    print('\n*** CONFIGURING CUSTOM IMAGE SETTINGS ***\n')
    max_width = 5472
    max_height = 3648
    set_width = int(max_width/downsize_width)
    set_height = int(max_height/downsize_height)
    set_offset_x = int((max_width-set_width)/2)
    set_offset_y = int((max_height-set_height)/2)
    acquisition_frame_rate = acquisition_frame_rate #frames per second
    exposure_time_to_set = exposure_time_to_set #milliseconds
    gain_to_set = gain_to_set
      
    try:
        result = True
        
        #WIDTH
        if cam.Width.GetAccessMode() == PySpin.RW and cam.Width.GetInc() != 0 and cam.Width.GetMax != 0:
            cam.Width.SetValue(set_width)
            print('Width set to %i...' % cam.Width.GetValue())
        else:
            print('Width not available...')
            result = False
        
        #HEIGHT
        if cam.Height.GetAccessMode() == PySpin.RW and cam.Height.GetInc() != 0 and cam.Height.GetMax != 0:
            cam.Height.SetValue(set_height)
            print('Height set to %i...' % cam.Height.GetValue())
        else:
            print('Height not available...')
            result = False

        #OFFSET X
        if cam.OffsetX.GetAccessMode() == PySpin.RW:
            cam.OffsetX.SetValue(set_offset_x)
            print('Offset X set to %d...' % cam.OffsetX.GetValue())

        else:
            print('Offset X not available...')
            result = False
        
        #OFFSET Y
        if cam.OffsetY.GetAccessMode() == PySpin.RW:
            cam.OffsetY.SetValue(set_offset_y)
            print('Offset Y set to %d...' % cam.OffsetY.GetValue())

        else:
            print('Offset Y not available...')
            result = False
        
        #EXPOSURE
        if cam.ExposureAuto.GetAccessMode() != PySpin.RW:
            print('Unable to disable automatic exposure. Aborting...')
            return False

        cam.ExposureAuto.SetValue(PySpin.ExposureAuto_Off)
        print('Automatic exposure disabled...')

        if cam.ExposureTime.GetAccessMode() != PySpin.RW:
            print('Unable to set exposure time. Aborting...')
            return False

        # Ensure desired exposure time does not exceed the maximum
        exposure_time_to_set = min(cam.ExposureTime.GetMax(), exposure_time_to_set)
        cam.ExposureTime.SetValue(exposure_time_to_set)
        
        #GAIN
        if cam.GainAuto.GetAccessMode() != PySpin.RW:
            print('Unable to disable automatic gain. Aborting...')
            return False

        cam.GainAuto.SetValue(PySpin.GainAuto_Off)
        print('Automatic gain disabled...')

        if cam.Gain.GetAccessMode() != PySpin.RW:
            print('Unable to set exposure time. Aborting...')
            return False

        # Ensure desired gain does not exceed the maximum
        gain_to_set = min(cam.Gain.GetMax(), gain_to_set)
        cam.Gain.SetValue(gain_to_set)
        
        #FRAME RATE
        cam.AcquisitionFrameRateEnable.SetValue(True)
        cam.AcquisitionFrameRate.SetValue(acquisition_frame_rate)    
        print("Acquisition frame rate set to %3.4f Hz..." % cam.AcquisitionFrameRate.GetValue())        
        
    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return False

    return result

def configure_chunk_data(nodemap):
    """
    This function configures the camera to add chunk data to each image. It does
    this by enabling each type of chunk data before enabling chunk data mode.
    When chunk data is turned on, the data is made available in both the nodemap
    and each image.

    :param nodemap: Transport layer device nodemap.
    :type nodemap: INodeMap
    :return: True if successful, False otherwise
    :rtype: bool
    """
    try:
        result = True
        print('\n*** CONFIGURING CHUNK DATA ***\n')

        # Activate chunk mode
        chunk_mode_active = PySpin.CBooleanPtr(nodemap.GetNode('ChunkModeActive'))

        if PySpin.IsAvailable(chunk_mode_active) and PySpin.IsWritable(chunk_mode_active):
            chunk_mode_active.SetValue(True)

        print('Chunk mode activated...')

        # Enable all types of chunk data
        chunk_selector = PySpin.CEnumerationPtr(nodemap.GetNode('ChunkSelector'))

        if not PySpin.IsAvailable(chunk_selector) or not PySpin.IsReadable(chunk_selector):
            print('Unable to retrieve chunk selector. Aborting...\n')
            return False

        # Retrieve entries
        entries = [PySpin.CEnumEntryPtr(chunk_selector_entry) for chunk_selector_entry in chunk_selector.GetEntries()]

        print('Enabling entries...')

        # Iterate through our list and select each entry node to enable
        for chunk_selector_entry in entries:
            # Go to next node if problem occurs
            if not PySpin.IsAvailable(chunk_selector_entry) or not PySpin.IsReadable(chunk_selector_entry):
                continue

            chunk_selector.SetIntValue(chunk_selector_entry.GetValue())

            chunk_str = '\t {}:'.format(chunk_selector_entry.GetSymbolic())

            # Retrieve corresponding boolean
            chunk_enable = PySpin.CBooleanPtr(nodemap.GetNode('ChunkEnable'))

            # Enable the boolean, thus enabling the corresponding chunk data
            if not PySpin.IsAvailable(chunk_enable):
                print('{} not available'.format(chunk_str))
                result = False
            elif chunk_enable.GetValue() is True:
                print('{} enabled'.format(chunk_str))
            elif PySpin.IsWritable(chunk_enable):
                chunk_enable.SetValue(True)
                print('{} enabled'.format(chunk_str))
            else:
                print('{} not writable'.format(chunk_str))
                result = False

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        result = False

    return result

def reset_exposure(cam):
    """
    This function returns the camera to a normal state by re-enabling automatic exposure.

    :param cam: Camera to reset exposure on.
    :type cam: CameraPtr
    :return: True if successful, False otherwise.
    :rtype: bool
    """
    try:
        result = True

        # Turn automatic exposure back on
        #
        # *** NOTES ***
        # Automatic exposure is turned on in order to return the camera to its
        # default state.

        if cam.ExposureAuto.GetAccessMode() != PySpin.RW:
            print('Unable to enable automatic exposure (node retrieval). Non-fatal error...')
            return False

        cam.ExposureAuto.SetValue(PySpin.ExposureAuto_Continuous)

        print('Automatic exposure enabled...')
        
        if cam.GainAuto.GetAccessMode() != PySpin.RW:
            print('Unable to disable automatic gain. Aborting...')
            return False
        
        cam.GainAuto.SetValue(PySpin.GainAuto_Continuous)
        
        print('Automatic gain enabled...')
        
    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        result = False

    return result

def print_device_info(cam):
    """
    This function prints the device information of the camera from the transport
    layer; please see NodeMapInfo example for more in-depth comments on printing
    device information from the nodemap.

    :param cam: Camera to get device information from.
    :type cam: CameraPtr
    :return: True if successful, False otherwise.
    :rtype: bool
    """

    print('\n*** DEVICE INFORMATION ***\n')

    try:
        result = True
        nodemap = cam.GetTLDeviceNodeMap()

        node_device_information = PySpin.CCategoryPtr(nodemap.GetNode('DeviceInformation'))

        if PySpin.IsAvailable(node_device_information) and PySpin.IsReadable(node_device_information):
            features = node_device_information.GetFeatures()
            for feature in features:
                node_feature = PySpin.CValuePtr(feature)
                print('%s: %s' % (node_feature.GetName(),
                                  node_feature.ToString() if PySpin.IsReadable(node_feature) else 'Node not readable'))

        else:
            print('Device control information not available.')

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex.message)
        return False

    return result

def check_or_create_dir(dirs, cwd=os.getcwd()):
    """
    This function iterates through a list of strings and creates nested directories with the string names if they don't already exist

    :param dirs: list of strings to created nested directories in sequential order \
    :param cwd: current working directory, default = os.getcwd() 
    """
    if len(dirs) > 0:
        if not os.path.exists(dirs[0]):
            os.mkdir(dirs[0])
            check_or_create_dir(dirs, cwd)
        else:
            os.chdir(dirs[0])
            dirs.pop(0)
            check_or_create_dir(dirs,cwd)
    else:
        os.chdir(cwd)
        
        
def acquire_images(cam, sample, num_images):
    """
    This function acquires and saves user-defined number of images from a device; please see
    Acquisition example for more in-depth comments on the acquisition of images.

    :param cam: Camera to acquire images from.
    :param sample: sample name for creating directories and filename for saving
    :param num_iamges: number of images to acquire
    :type cam: CameraPtr
    :return: True if successful, False otherwise.
    :rtype: bool
    """
    print('\n*** IMAGE ACQUISITION ***\n')

    try:
        result = True

        # Set acquisition mode to continuous
        if cam.AcquisitionMode.GetAccessMode() != PySpin.RW:
            print('Unable to set acquisition mode to continuous. Aborting...')
            return False

        cam.AcquisitionMode.SetValue(PySpin.AcquisitionMode_Continuous)
        print('Acquisition mode set to continuous...')

        # Begin acquiring images
        cam.BeginAcquisition()

        print('Acquiring images...')

        # Get device serial number for filename
        device_serial_number = ''
        if cam.TLDevice.DeviceSerialNumber is not None and cam.TLDevice.DeviceSerialNumber.GetAccessMode() == PySpin.RO:
            device_serial_number = cam.TLDevice.DeviceSerialNumber.GetValue()

            print('Device serial number retrieved as %s...' % device_serial_number)

        # Retrieve, convert, and save images
        for i in range(num_images):

            try:
                # Retrieve next received image and ensure image completion
                image_result = cam.GetNextImage()

                if image_result.IsIncomplete():
                    print('Image incomplete with image status %d...' % image_result.GetImageStatus())

                else:
                    # Print image information
                    width = image_result.GetWidth()
                    height = image_result.GetHeight()
                    print('Grabbed Image %d, width = %d, height = %d' % (i, width, height))

                    # Convert image to Mono8
                    #image_converted = image_result.Convert(PySpin.PixelFormat_Mono8)
                    chunk_data = image_result.GetChunkData()
                    
                    # Retrieve frame ID
                    frame_id = chunk_data.GetFrameID()
                    # Retrieve timestamp
                    timestamp = chunk_data.GetTimestamp()
                    #today's date
                    today_date = datetime.date(datetime.today()).isoformat()
                    #acquisition_frame_rate
                    acq_frame_rate = str(int(round(cam.AcquisitionFrameRate.GetValue())))+'Hz'
                    
                    
                    # Create a unique filename
                    if chunk_data:
                        filename = '%s_%s_%s_%s_%04d.tif' % (today_date,str(sample),timestamp,acq_frame_rate, i)
                    
                    abs_path = os.path.join(os.getcwd(),sample.replace('_', '\\'),filename)
                    
                    # Save image
                    TIFF_format = PySpin.TIFFOption()
                    TIFF_format.compression = PySpin.TIFFOption.NONE
                    image_result.Save(abs_path, TIFF_format)

                    print('Image saved at %s' % filename)

                # Release image
                image_result.Release()

            except PySpin.SpinnakerException as ex:
                print('Error: %s' % ex)
                result = False

        # End acquisition
        cam.EndAcquisition()

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        result = False

    return result

def run_single_camera(cam, 
    sample,
    num_images,
    downsize_width,
    downsize_height,
    acquisition_frame_rate, 
    exposure_time_to_set,
    gain_to_set):
    """
     This function acts as the body of the example; please see NodeMapInfo_QuickSpin example for more
     in-depth comments on setting up cameras.

     :param cam: Camera to run example on.
     :type cam: CameraPtr
     :return: True if successful, False otherwise.
     :rtype: bool
    """
    try:
        # Initialize camera
        cam.Init()

        # Print device info
        result = print_device_info(cam)

        # Configure camera settings
        if not configure_custom_image_settings(cam,
            num_images,
            downsize_width,
            downsize_height,
            acquisition_frame_rate, 
            exposure_time_to_set,
            gain_to_set):
            return False
        
        # Retrieve GenICam nodemap
        nodemap = cam.GetNodeMap()
        
        # Configure chunk data
        if configure_chunk_data(nodemap) is False:
            return False
        
        # Acquire images
        result &= acquire_images(cam=cam, sample=sample, num_images=num_images)
        
        #reset exposure modes
        reset_exposure(cam)
        # Deinitialize camera
        cam.DeInit()

        return result

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return False

# %%
def begin_capture(sample,
    num_images = 10,
    downsize_width = 2,
    downsize_height = 2,
    acquisition_frame_rate = 3, 
    exposure_time_to_set = 15000.0,
    gain_to_set = 6.29):
    
    result = True
    # Get system
    system = PySpin.System.GetInstance()
    # Get camera list
    cam_list = system.GetCameras()
    num_cameras = cam_list.GetSize()

    print('Number of cameras detected: %d' % num_cameras)
    # Finish if there are no cameras
    if num_cameras == 0:
        # Clear camera list before releasing system
        cam_list.Clear()

        # Release system instance
        system.ReleaseInstance()

        print('Not enough cameras!')
        return False
    
    check_or_create_dir(sample.split('_'), cwd=os.getcwd())
    
    cam = cam_list.GetByIndex(0)
    result &= run_single_camera(cam, 
                sample,
                num_images,
                downsize_width,
                downsize_height,
                acquisition_frame_rate, 
                exposure_time_to_set,
                gain_to_set)
    
    del cam
    cam_list.Clear()
    system.ReleaseInstance()
    print("Done!")
    return result

# %%
#RUN USB CAMERA

# %%
capture_time = 25 # minutes
capture_time = capture_time * 60 #seconds
acquisition_rate = 2 #Hz
num_images = capture_time*acquisition_rate
# num_images=10 #OVERRIDE FOR TESTING
sample_name = 'DAY14_SFMPLUS_B2' # underscore will be divided into sub-directories when saving e.g. 'SFM_DAY4_A1' will be saved in folder SFM\\DAY4\\A1
downsize_width = 6
downsize_height = 1
# exposure_time_to_set
# gain_to_set

# %%
#BEGIN CAPTURE
begin_capture(sample=sample_name, num_images=num_images, acquisition_frame_rate=acquisition_rate, downsize_width=downsize_width, downsize_height=downsize_height)
# Out:
# Number of cameras detected: 1
#
# *** DEVICE INFORMATION ***
#
# DeviceID: 18474805
# DeviceSerialNumber: 18474805
# DeviceVendorName: FLIR
# DeviceModelName: Blackfly S BFS-U3-200S6C
# DeviceType: U3V
# DeviceDisplayName: FLIR Blackfly S BFS-U3-200S6C
# DeviceAccessStatus: ReadWrite
# DeviceVersion: 1705.0.124.0
# DeviceDriverVersion: PGRUSBCam3.sys : 2.7.3.249
# DeviceUserID:
# DeviceIsUpdater: 0
# DeviceInstanceId: USB\VID_1E10&PID_4000&MI_00\8&356F58B8&0&0000
# DeviceCurrentSpeed: SuperSpeed
# GUIXMLLocation: Device
# GUIXMLPath: Input.xml
# GenICamXMLLocation: Device
# GenICamXMLPath:
# DeviceU3VProtocol: 1
#
# *** CONFIGURING CUSTOM IMAGE SETTINGS ***
#
# Width set to 912...
# Height set to 3648...
# Offset X set to 2280...
# Offset Y set to 0...
# Automatic exposure disabled...
# Automatic gain disabled...
# Acquisition frame rate set to 2.0000 Hz...
#
# *** CONFIGURING CHUNK DATA ***
#
# Chunk mode activated...
# Enabling entries...
# 	 Image: enabled
# 	 CRC: enabled
# 	 FrameID: enabled
# 	 OffsetX: enabled
# 	 OffsetY: enabled
# 	 Width: enabled
# 	 Height: enabled
# 	 ExposureTime: enabled
# 	 Gain: enabled
# 	 BlackLevel: enabled
# 	 PixelFormat: enabled
# 	 Timestamp: enabled
# 	 SequencerSetActive: enabled
# 	 SerialData: enabled
# 	 ExposureEndLineStatusAll: enabled
#
# *** IMAGE ACQUISITION ***
#
# Acquisition mode set to continuous...
# Acquiring images...
# Device serial number retrieved as 18474805...
# Grabbed Image 0, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18643834586368_2Hz_0000.tif
# Grabbed Image 1, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18644334586024_2Hz_0001.tif
# Grabbed Image 2, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18644834586744_2Hz_0002.tif
# Grabbed Image 3, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18645334586040_2Hz_0003.tif
# Grabbed Image 4, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18645834586496_2Hz_0004.tif
# Grabbed Image 5, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18646334585744_2Hz_0005.tif
# Grabbed Image 6, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18646834585944_2Hz_0006.tif
# Grabbed Image 7, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18647334585608_2Hz_0007.tif
# Grabbed Image 8, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18647834585464_2Hz_0008.tif
# Grabbed Image 9, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18648334585560_2Hz_0009.tif
# Grabbed Image 10, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18648834585560_2Hz_0010.tif
# Grabbed Image 11, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18649334585408_2Hz_0011.tif
# Grabbed Image 12, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18649834585448_2Hz_0012.tif
# Grabbed Image 13, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18650334585304_2Hz_0013.tif
# Grabbed Image 14, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18650834585560_2Hz_0014.tif
# Grabbed Image 15, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18651334585384_2Hz_0015.tif
# Grabbed Image 16, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18651834585184_2Hz_0016.tif
# Grabbed Image 17, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18652334584832_2Hz_0017.tif
# Grabbed Image 18, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18652834584840_2Hz_0018.tif
# Grabbed Image 19, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18653334584608_2Hz_0019.tif
# Grabbed Image 20, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18653834584464_2Hz_0020.tif
# Grabbed Image 21, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18654334584608_2Hz_0021.tif
# Grabbed Image 22, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18654834584520_2Hz_0022.tif
# Grabbed Image 23, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18655334584208_2Hz_0023.tif
# Grabbed Image 24, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18655834584592_2Hz_0024.tif
# Grabbed Image 25, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18656334584808_2Hz_0025.tif
# Grabbed Image 26, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18656834584424_2Hz_0026.tif
# Grabbed Image 27, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18657334584552_2Hz_0027.tif
# Grabbed Image 28, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18657834584024_2Hz_0028.tif
# Grabbed Image 29, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18658334584288_2Hz_0029.tif
# Grabbed Image 30, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18658834584312_2Hz_0030.tif
# Grabbed Image 31, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18659334584448_2Hz_0031.tif
# Grabbed Image 32, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18659834583520_2Hz_0032.tif
# Grabbed Image 33, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18660334583608_2Hz_0033.tif
# Grabbed Image 34, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18660834583368_2Hz_0034.tif
# Grabbed Image 35, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18661334584112_2Hz_0035.tif
# Grabbed Image 36, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18661834583608_2Hz_0036.tif
# Grabbed Image 37, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18662334583944_2Hz_0037.tif
# Grabbed Image 38, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18662834583224_2Hz_0038.tif
# Grabbed Image 39, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18663334583448_2Hz_0039.tif
# Grabbed Image 40, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18663834583040_2Hz_0040.tif
# Grabbed Image 41, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18664334583272_2Hz_0041.tif
# Grabbed Image 42, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18664834583448_2Hz_0042.tif
# Grabbed Image 43, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18665334582560_2Hz_0043.tif
# Grabbed Image 44, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18665834583408_2Hz_0044.tif
# Grabbed Image 45, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18666334582608_2Hz_0045.tif
# Grabbed Image 46, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18666834582616_2Hz_0046.tif
# Grabbed Image 47, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18667334582448_2Hz_0047.tif
# Grabbed Image 48, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18667834582144_2Hz_0048.tif
# Grabbed Image 49, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18668334582784_2Hz_0049.tif
# Grabbed Image 50, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18668834582592_2Hz_0050.tif
# Grabbed Image 51, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18669334582688_2Hz_0051.tif
# Grabbed Image 52, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18669834582464_2Hz_0052.tif
# Grabbed Image 53, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18670334582608_2Hz_0053.tif
# Grabbed Image 54, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18670834582384_2Hz_0054.tif
# Grabbed Image 55, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18671334581800_2Hz_0055.tif
# Grabbed Image 56, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18671834581928_2Hz_0056.tif
# Grabbed Image 57, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18672334581560_2Hz_0057.tif
# Grabbed Image 58, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18672834582328_2Hz_0058.tif
# Grabbed Image 59, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18673334582064_2Hz_0059.tif
# Grabbed Image 60, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18673834582056_2Hz_0060.tif
# Grabbed Image 61, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18674334581728_2Hz_0061.tif
# Grabbed Image 62, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18674834581248_2Hz_0062.tif
# Grabbed Image 63, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18675334581448_2Hz_0063.tif
# Grabbed Image 64, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18675834581784_2Hz_0064.tif
# Grabbed Image 65, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18676334581728_2Hz_0065.tif
# Grabbed Image 66, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18676834580800_2Hz_0066.tif
# Grabbed Image 67, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18677334581280_2Hz_0067.tif
# Grabbed Image 68, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18677834581312_2Hz_0068.tif
# Grabbed Image 69, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18678334581336_2Hz_0069.tif
# Grabbed Image 70, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18678834580688_2Hz_0070.tif
# Grabbed Image 71, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18679334580448_2Hz_0071.tif
# Grabbed Image 72, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18679834580840_2Hz_0072.tif
# Grabbed Image 73, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18680334580744_2Hz_0073.tif
# Grabbed Image 74, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18680834580616_2Hz_0074.tif
# Grabbed Image 75, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18681334580664_2Hz_0075.tif
# Grabbed Image 76, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18681834580312_2Hz_0076.tif
# Grabbed Image 77, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18682334580304_2Hz_0077.tif
# Grabbed Image 78, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18682834580608_2Hz_0078.tif
# Grabbed Image 79, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18683334580272_2Hz_0079.tif
# Grabbed Image 80, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18683834579712_2Hz_0080.tif
# Grabbed Image 81, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18684334579800_2Hz_0081.tif
# Grabbed Image 82, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18684834579616_2Hz_0082.tif
# Grabbed Image 83, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18685334579560_2Hz_0083.tif
# Grabbed Image 84, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18685834580064_2Hz_0084.tif
# Grabbed Image 85, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18686334579728_2Hz_0085.tif
# Grabbed Image 86, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18686834579592_2Hz_0086.tif
# Grabbed Image 87, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18687334579872_2Hz_0087.tif
# Grabbed Image 88, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18687834579592_2Hz_0088.tif
# Grabbed Image 89, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18688334579664_2Hz_0089.tif
# Grabbed Image 90, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18688834579384_2Hz_0090.tif
# Grabbed Image 91, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18689334579592_2Hz_0091.tif
# Grabbed Image 92, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18689834579080_2Hz_0092.tif
# Grabbed Image 93, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18690334578688_2Hz_0093.tif
# Grabbed Image 94, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18690834578960_2Hz_0094.tif
# Grabbed Image 95, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18691334578608_2Hz_0095.tif
# Grabbed Image 96, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18691834578520_2Hz_0096.tif
# Grabbed Image 97, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18692334579168_2Hz_0097.tif
# Grabbed Image 98, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18692834578784_2Hz_0098.tif
# Grabbed Image 99, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18693334578336_2Hz_0099.tif
# Grabbed Image 100, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18693834578568_2Hz_0100.tif
# Grabbed Image 101, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18694334578264_2Hz_0101.tif
# Grabbed Image 102, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18694834577944_2Hz_0102.tif
# Grabbed Image 103, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18695334578448_2Hz_0103.tif
# Grabbed Image 104, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18695834577984_2Hz_0104.tif
# Grabbed Image 105, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18696334577648_2Hz_0105.tif
# Grabbed Image 106, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18696834577760_2Hz_0106.tif
# Grabbed Image 107, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18697334577608_2Hz_0107.tif
# Grabbed Image 108, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18697834578008_2Hz_0108.tif
# Grabbed Image 109, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18698334577560_2Hz_0109.tif
# Grabbed Image 110, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18698834577504_2Hz_0110.tif
# Grabbed Image 111, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18699334578064_2Hz_0111.tif
# Grabbed Image 112, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18699834577184_2Hz_0112.tif
# Grabbed Image 113, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18700334577832_2Hz_0113.tif
# Grabbed Image 114, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18700834577704_2Hz_0114.tif
# Grabbed Image 115, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18701334577552_2Hz_0115.tif
# Grabbed Image 116, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18701834577464_2Hz_0116.tif
# Grabbed Image 117, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18702334576800_2Hz_0117.tif
# Grabbed Image 118, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18702834577288_2Hz_0118.tif
# Grabbed Image 119, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18703334577448_2Hz_0119.tif
# Grabbed Image 120, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18703834576592_2Hz_0120.tif
# Grabbed Image 121, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18704334576760_2Hz_0121.tif
# Grabbed Image 122, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18704834576552_2Hz_0122.tif
# Grabbed Image 123, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18705334576368_2Hz_0123.tif
# Grabbed Image 124, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18705834576760_2Hz_0124.tif
# Grabbed Image 125, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18706334576728_2Hz_0125.tif
# Grabbed Image 126, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18706834576552_2Hz_0126.tif
# Grabbed Image 127, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18707334576112_2Hz_0127.tif
# Grabbed Image 128, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18707834576608_2Hz_0128.tif
# Grabbed Image 129, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18708334575832_2Hz_0129.tif
# Grabbed Image 130, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18708834575984_2Hz_0130.tif
# Grabbed Image 131, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18709334576408_2Hz_0131.tif
# Grabbed Image 132, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18709834575448_2Hz_0132.tif
# Grabbed Image 133, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18710334575464_2Hz_0133.tif
# Grabbed Image 134, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18710834576144_2Hz_0134.tif
# Grabbed Image 135, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18711334575448_2Hz_0135.tif
# Grabbed Image 136, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18711834575592_2Hz_0136.tif
# Grabbed Image 137, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18712334575800_2Hz_0137.tif
# Grabbed Image 138, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18712834575560_2Hz_0138.tif
# Grabbed Image 139, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18713334575040_2Hz_0139.tif
# Grabbed Image 140, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18713834575592_2Hz_0140.tif
# Grabbed Image 141, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18714334574832_2Hz_0141.tif
# Grabbed Image 142, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18714834575288_2Hz_0142.tif
# Grabbed Image 143, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18715334574616_2Hz_0143.tif
# Grabbed Image 144, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18715834575040_2Hz_0144.tif
# Grabbed Image 145, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18716334574664_2Hz_0145.tif
# Grabbed Image 146, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18716834575264_2Hz_0146.tif
# Grabbed Image 147, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18717334575024_2Hz_0147.tif
# Grabbed Image 148, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18717834574368_2Hz_0148.tif
# Grabbed Image 149, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18718334574800_2Hz_0149.tif
# Grabbed Image 150, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18718834574784_2Hz_0150.tif
# Grabbed Image 151, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18719334574448_2Hz_0151.tif
# Grabbed Image 152, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18719834573984_2Hz_0152.tif
# Grabbed Image 153, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18720334573784_2Hz_0153.tif
# Grabbed Image 154, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18720834573832_2Hz_0154.tif
# Grabbed Image 155, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18721334573608_2Hz_0155.tif
# Grabbed Image 156, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18721834574464_2Hz_0156.tif
# Grabbed Image 157, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18722334574304_2Hz_0157.tif
# Grabbed Image 158, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18722834573784_2Hz_0158.tif
# Grabbed Image 159, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18723334574040_2Hz_0159.tif
# Grabbed Image 160, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18723834573424_2Hz_0160.tif
# Grabbed Image 161, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18724334573728_2Hz_0161.tif
# Grabbed Image 162, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18724834573560_2Hz_0162.tif
# Grabbed Image 163, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18725334573560_2Hz_0163.tif
# Grabbed Image 164, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18725834573336_2Hz_0164.tif
# Grabbed Image 165, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18726334573704_2Hz_0165.tif
# Grabbed Image 166, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18726834572800_2Hz_0166.tif
# Grabbed Image 167, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18727334573384_2Hz_0167.tif
# Grabbed Image 168, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18727834572592_2Hz_0168.tif
# Grabbed Image 169, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18728334572784_2Hz_0169.tif
# Grabbed Image 170, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18728834572448_2Hz_0170.tif
# Grabbed Image 171, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18729334572320_2Hz_0171.tif
# Grabbed Image 172, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18729834572464_2Hz_0172.tif
# Grabbed Image 173, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18730334572784_2Hz_0173.tif
# Grabbed Image 174, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18730834572728_2Hz_0174.tif
# Grabbed Image 175, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18731334572384_2Hz_0175.tif
# Grabbed Image 176, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18731834572592_2Hz_0176.tif
# Grabbed Image 177, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18732334572784_2Hz_0177.tif
# Grabbed Image 178, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18732834571784_2Hz_0178.tif
# Grabbed Image 179, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18733334572384_2Hz_0179.tif
# Grabbed Image 180, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18733834571592_2Hz_0180.tif
# Grabbed Image 181, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18734334571944_2Hz_0181.tif
# Grabbed Image 182, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18734834572248_2Hz_0182.tif
# Grabbed Image 183, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18735334572064_2Hz_0183.tif
# Grabbed Image 184, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18735834572080_2Hz_0184.tif
# Grabbed Image 185, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18736334571800_2Hz_0185.tif
# Grabbed Image 186, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18736834571560_2Hz_0186.tif
# Grabbed Image 187, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18737334571328_2Hz_0187.tif
# Grabbed Image 188, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18737834571368_2Hz_0188.tif
# Grabbed Image 189, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18738334571664_2Hz_0189.tif
# Grabbed Image 190, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18738834571208_2Hz_0190.tif
# Grabbed Image 191, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18739334571448_2Hz_0191.tif
# Grabbed Image 192, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18739834570712_2Hz_0192.tif
# Grabbed Image 193, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18740334571464_2Hz_0193.tif
# Grabbed Image 194, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18740834571064_2Hz_0194.tif
# Grabbed Image 195, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18741334570520_2Hz_0195.tif
# Grabbed Image 196, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18741834570688_2Hz_0196.tif
# Grabbed Image 197, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18742334570888_2Hz_0197.tif
# Grabbed Image 198, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18742834570264_2Hz_0198.tif
# Grabbed Image 199, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18743334570384_2Hz_0199.tif
# Grabbed Image 200, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18743834570464_2Hz_0200.tif
# Grabbed Image 201, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18744334569984_2Hz_0201.tif
# Grabbed Image 202, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18744834569832_2Hz_0202.tif
# Grabbed Image 203, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18745334570112_2Hz_0203.tif
# Grabbed Image 204, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18745834570368_2Hz_0204.tif
# Grabbed Image 205, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18746334569664_2Hz_0205.tif
# Grabbed Image 206, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18746834569592_2Hz_0206.tif
# Grabbed Image 207, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18747334570328_2Hz_0207.tif
# Grabbed Image 208, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18747834569592_2Hz_0208.tif
# Grabbed Image 209, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18748334569840_2Hz_0209.tif
# Grabbed Image 210, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18748834569840_2Hz_0210.tif
# Grabbed Image 211, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18749334569592_2Hz_0211.tif
# Grabbed Image 212, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18749834569464_2Hz_0212.tif
# Grabbed Image 213, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18750334569832_2Hz_0213.tif
# Grabbed Image 214, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18750834569384_2Hz_0214.tif
# Grabbed Image 215, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18751334569064_2Hz_0215.tif
# Grabbed Image 216, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18751834569184_2Hz_0216.tif
# Grabbed Image 217, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18752334569208_2Hz_0217.tif
# Grabbed Image 218, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18752834568552_2Hz_0218.tif
# Grabbed Image 219, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18753334568560_2Hz_0219.tif
# Grabbed Image 220, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18753834568992_2Hz_0220.tif
# Grabbed Image 221, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18754334568784_2Hz_0221.tif
# Grabbed Image 222, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18754834568592_2Hz_0222.tif
# Grabbed Image 223, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18755334568840_2Hz_0223.tif
# Grabbed Image 224, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18755834568984_2Hz_0224.tif
# Grabbed Image 225, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18756334568304_2Hz_0225.tif
# Grabbed Image 226, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18756834568560_2Hz_0226.tif
# Grabbed Image 227, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18757334568240_2Hz_0227.tif
# Grabbed Image 228, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18757834568080_2Hz_0228.tif
# Grabbed Image 229, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18758334567760_2Hz_0229.tif
# Grabbed Image 230, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18758834567944_2Hz_0230.tif
# Grabbed Image 231, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18759334567752_2Hz_0231.tif
# Grabbed Image 232, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18759834568384_2Hz_0232.tif
# Grabbed Image 233, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18760334567464_2Hz_0233.tif
# Grabbed Image 234, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18760834567272_2Hz_0234.tif
# Grabbed Image 235, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18761334567336_2Hz_0235.tif
# Grabbed Image 236, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18761834568040_2Hz_0236.tif
# Grabbed Image 237, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18762334567184_2Hz_0237.tif
# Grabbed Image 238, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18762834567520_2Hz_0238.tif
# Grabbed Image 239, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18763334567448_2Hz_0239.tif
# Grabbed Image 240, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18763834566888_2Hz_0240.tif
# Grabbed Image 241, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18764334567520_2Hz_0241.tif
# Grabbed Image 242, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18764834567208_2Hz_0242.tif
# Grabbed Image 243, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18765334567264_2Hz_0243.tif
# Grabbed Image 244, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18765834567056_2Hz_0244.tif
# Grabbed Image 245, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18766334566840_2Hz_0245.tif
# Grabbed Image 246, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18766834566608_2Hz_0246.tif
# Grabbed Image 247, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18767334566448_2Hz_0247.tif
# Grabbed Image 248, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18767834566592_2Hz_0248.tif
# Grabbed Image 249, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18768334567000_2Hz_0249.tif
# Grabbed Image 250, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18768834566944_2Hz_0250.tif
# Grabbed Image 251, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18769334566560_2Hz_0251.tif
# Grabbed Image 252, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18769834566464_2Hz_0252.tif
# Grabbed Image 253, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18770334566432_2Hz_0253.tif
# Grabbed Image 254, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18770834566552_2Hz_0254.tif
# Grabbed Image 255, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18771334565608_2Hz_0255.tif
# Grabbed Image 256, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18771834565520_2Hz_0256.tif
# Grabbed Image 257, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18772334565648_2Hz_0257.tif
# Grabbed Image 258, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18772834565464_2Hz_0258.tif
# Grabbed Image 259, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18773334565592_2Hz_0259.tif
# Grabbed Image 260, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18773834565448_2Hz_0260.tif
# Grabbed Image 261, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18774334565832_2Hz_0261.tif
# Grabbed Image 262, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18774834565264_2Hz_0262.tif
# Grabbed Image 263, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18775334565064_2Hz_0263.tif
# Grabbed Image 264, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18775834565040_2Hz_0264.tif
# Grabbed Image 265, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18776334565744_2Hz_0265.tif
# Grabbed Image 266, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18776834565408_2Hz_0266.tif
# Grabbed Image 267, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18777334565592_2Hz_0267.tif
# Grabbed Image 268, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18777834564592_2Hz_0268.tif
# Grabbed Image 269, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18778334564800_2Hz_0269.tif
# Grabbed Image 270, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18778834564872_2Hz_0270.tif
# Grabbed Image 271, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18779334564608_2Hz_0271.tif
# Grabbed Image 272, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18779834564384_2Hz_0272.tif
# Grabbed Image 273, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18780334564832_2Hz_0273.tif
# Grabbed Image 274, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18780834564784_2Hz_0274.tif
# Grabbed Image 275, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18781334564744_2Hz_0275.tif
# Grabbed Image 276, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18781834564496_2Hz_0276.tif
# Grabbed Image 277, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18782334564744_2Hz_0277.tif
# Grabbed Image 278, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18782834564664_2Hz_0278.tif
# Grabbed Image 279, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18783334564608_2Hz_0279.tif
# Grabbed Image 280, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18783834564384_2Hz_0280.tif
# Grabbed Image 281, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18784334563832_2Hz_0281.tif
# Grabbed Image 282, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18784834564240_2Hz_0282.tif
# Grabbed Image 283, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18785334563608_2Hz_0283.tif
# Grabbed Image 284, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18785834563464_2Hz_0284.tif
# Grabbed Image 285, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18786334563424_2Hz_0285.tif
# Grabbed Image 286, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18786834563560_2Hz_0286.tif
# Grabbed Image 287, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18787334563608_2Hz_0287.tif
# Grabbed Image 288, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18787834563592_2Hz_0288.tif
# Grabbed Image 289, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18788334563744_2Hz_0289.tif
# Grabbed Image 290, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18788834563008_2Hz_0290.tif
# Grabbed Image 291, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18789334563328_2Hz_0291.tif
# Grabbed Image 292, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18789834563448_2Hz_0292.tif
# Grabbed Image 293, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18790334562784_2Hz_0293.tif
# Grabbed Image 294, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18790834562744_2Hz_0294.tif
# Grabbed Image 295, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18791334562608_2Hz_0295.tif
# Grabbed Image 296, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18791834562520_2Hz_0296.tif
# Grabbed Image 297, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18792334562744_2Hz_0297.tif
# Grabbed Image 298, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18792834563024_2Hz_0298.tif
# Grabbed Image 299, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18793334562408_2Hz_0299.tif
# Grabbed Image 300, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18793834562368_2Hz_0300.tif
# Grabbed Image 301, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18794334562832_2Hz_0301.tif
# Grabbed Image 302, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18794834562368_2Hz_0302.tif
# Grabbed Image 303, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18795334562024_2Hz_0303.tif
# Grabbed Image 304, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18795834562608_2Hz_0304.tif
# Grabbed Image 305, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18796334561832_2Hz_0305.tif
# Grabbed Image 306, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18796834561768_2Hz_0306.tif
# Grabbed Image 307, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18797334561984_2Hz_0307.tif
# Grabbed Image 308, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18797834561448_2Hz_0308.tif
# Grabbed Image 309, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18798334561288_2Hz_0309.tif
# Grabbed Image 310, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18798834561560_2Hz_0310.tif
# Grabbed Image 311, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18799334561608_2Hz_0311.tif
# Grabbed Image 312, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18799834561368_2Hz_0312.tif
# Grabbed Image 313, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18800334561248_2Hz_0313.tif
# Grabbed Image 314, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18800834560872_2Hz_0314.tif
# Grabbed Image 315, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18801334561240_2Hz_0315.tif
# Grabbed Image 316, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18801834560808_2Hz_0316.tif
# Grabbed Image 317, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18802334561248_2Hz_0317.tif
# Grabbed Image 318, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18802834560760_2Hz_0318.tif
# Grabbed Image 319, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18803334561448_2Hz_0319.tif
# Grabbed Image 320, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18803834560688_2Hz_0320.tif
# Grabbed Image 321, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18804334560744_2Hz_0321.tif
# Grabbed Image 322, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18804834560688_2Hz_0322.tif
# Grabbed Image 323, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18805334560728_2Hz_0323.tif
# Grabbed Image 324, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18805834560368_2Hz_0324.tif
# Grabbed Image 325, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18806334560272_2Hz_0325.tif
# Grabbed Image 326, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18806834560592_2Hz_0326.tif
# Grabbed Image 327, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18807334560448_2Hz_0327.tif
# Grabbed Image 328, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18807834560424_2Hz_0328.tif
# Grabbed Image 329, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18808334560608_2Hz_0329.tif
# Grabbed Image 330, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18808834559744_2Hz_0330.tif
# Grabbed Image 331, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18809334560408_2Hz_0331.tif
# Grabbed Image 332, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18809834559968_2Hz_0332.tif
# Grabbed Image 333, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18810334559688_2Hz_0333.tif
# Grabbed Image 334, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18810834559480_2Hz_0334.tif
# Grabbed Image 335, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18811334559960_2Hz_0335.tif
# Grabbed Image 336, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18811834560040_2Hz_0336.tif
# Grabbed Image 337, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18812334559432_2Hz_0337.tif
# Grabbed Image 338, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18812834559832_2Hz_0338.tif
# Grabbed Image 339, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18813334558896_2Hz_0339.tif
# Grabbed Image 340, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18813834559464_2Hz_0340.tif
# Grabbed Image 341, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18814334559664_2Hz_0341.tif
# Grabbed Image 342, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18814834558840_2Hz_0342.tif
# Grabbed Image 343, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18815334558608_2Hz_0343.tif
# Grabbed Image 344, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18815834559080_2Hz_0344.tif
# Grabbed Image 345, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18816334558480_2Hz_0345.tif
# Grabbed Image 346, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18816834558888_2Hz_0346.tif
# Grabbed Image 347, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18817334558560_2Hz_0347.tif
# Grabbed Image 348, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18817834558448_2Hz_0348.tif
# Grabbed Image 349, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18818334558800_2Hz_0349.tif
# Grabbed Image 350, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18818834558312_2Hz_0350.tif
# Grabbed Image 351, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18819334558752_2Hz_0351.tif
# Grabbed Image 352, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18819834558384_2Hz_0352.tif
# Grabbed Image 353, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18820334557760_2Hz_0353.tif
# Grabbed Image 354, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18820834557928_2Hz_0354.tif
# Grabbed Image 355, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18821334557888_2Hz_0355.tif
# Grabbed Image 356, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18821834558384_2Hz_0356.tif
# Grabbed Image 357, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18822334557744_2Hz_0357.tif
# Grabbed Image 358, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18822834557520_2Hz_0358.tif
# Grabbed Image 359, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18823334557312_2Hz_0359.tif
# Grabbed Image 360, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18823834557520_2Hz_0360.tif
# Grabbed Image 361, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18824334558048_2Hz_0361.tif
# Grabbed Image 362, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18824834557784_2Hz_0362.tif
# Grabbed Image 363, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18825334557408_2Hz_0363.tif
# Grabbed Image 364, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18825834557336_2Hz_0364.tif
# Grabbed Image 365, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18826334556832_2Hz_0365.tif
# Grabbed Image 366, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18826834557424_2Hz_0366.tif
# Grabbed Image 367, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18827334557448_2Hz_0367.tif
# Grabbed Image 368, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18827834556896_2Hz_0368.tif
# Grabbed Image 369, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18828334556616_2Hz_0369.tif
# Grabbed Image 370, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18828834556424_2Hz_0370.tif
# Grabbed Image 371, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18829334556648_2Hz_0371.tif
# Grabbed Image 372, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18829834556592_2Hz_0372.tif
# Grabbed Image 373, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18830334556784_2Hz_0373.tif
# Grabbed Image 374, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18830834556384_2Hz_0374.tif
# Grabbed Image 375, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18831334556240_2Hz_0375.tif
# Grabbed Image 376, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18831834556040_2Hz_0376.tif
# Grabbed Image 377, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18832334556784_2Hz_0377.tif
# Grabbed Image 378, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18832834555896_2Hz_0378.tif
# Grabbed Image 379, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18833334556560_2Hz_0379.tif
# Grabbed Image 380, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18833834555808_2Hz_0380.tif
# Grabbed Image 381, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18834334555832_2Hz_0381.tif
# Grabbed Image 382, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18834834555592_2Hz_0382.tif
# Grabbed Image 383, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18835334555608_2Hz_0383.tif
# Grabbed Image 384, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18835834555448_2Hz_0384.tif
# Grabbed Image 385, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18836334555760_2Hz_0385.tif
# Grabbed Image 386, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18836834556080_2Hz_0386.tif
# Grabbed Image 387, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18837334555560_2Hz_0387.tif
# Grabbed Image 388, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18837834555064_2Hz_0388.tif
# Grabbed Image 389, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18838334555384_2Hz_0389.tif
# Grabbed Image 390, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18838834554832_2Hz_0390.tif
# Grabbed Image 391, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18839334555608_2Hz_0391.tif
# Grabbed Image 392, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18839834555552_2Hz_0392.tif
# Grabbed Image 393, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18840334555448_2Hz_0393.tif
# Grabbed Image 394, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18840834555336_2Hz_0394.tif
# Grabbed Image 395, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18841334554888_2Hz_0395.tif
# Grabbed Image 396, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18841834554424_2Hz_0396.tif
# Grabbed Image 397, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18842334554744_2Hz_0397.tif
# Grabbed Image 398, width = 912, height = 3648
# Image saved at 2019-03-11_DAY14_SFMPLUS_B2_18842834554504_2Hz_0398.tif
# Grabbed Image 399, width = 912, height = 3648
# ...
# Grabbed Image 2893, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2894, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2895, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2896, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2897, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2898, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2899, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2900, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2901, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2902, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2903, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2904, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2905, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2906, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2907, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2908, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2909, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2910, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2911, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2912, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2913, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2914, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2915, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2916, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2917, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2918, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2919, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2920, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2921, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2922, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2923, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2924, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2925, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2926, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2927, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2928, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2929, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2930, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2931, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2932, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2933, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2934, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2935, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2936, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2937, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2938, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2939, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2940, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2941, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2942, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2943, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2944, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2945, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2946, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2947, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2948, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2949, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2950, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2951, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2952, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2953, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2954, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2955, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2956, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2957, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2958, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2959, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2960, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2961, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2962, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2963, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2964, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2965, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2966, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2967, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2968, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2969, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2970, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2971, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2972, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2973, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2974, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2975, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2976, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2977, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2978, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2979, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2980, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2981, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2982, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2983, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2984, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2985, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2986, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2987, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2988, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2989, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2990, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2991, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2992, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2993, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2994, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2995, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2996, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2997, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2998, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Grabbed Image 2999, width = 912, height = 3648
# Error: Spinnaker: Failed calling FreeImage to save pixel format 27 to output image format 5. [-1001]
# Automatic exposure enabled...
# Automatic gain enabled...
# Done!
# False

# %%
# %run Examples\\Python3\\ChunkData.py
# Out:
# Library version: 1.19.0.22
# Number of cameras detected: 1
# Running example for camera 0...
#
# *** DEVICE INFORMATION ***
#
# DeviceID: 18474805
# DeviceSerialNumber: 18474805
# DeviceVendorName: FLIR
# DeviceModelName: Blackfly S BFS-U3-200S6C
# DeviceType: U3V
# DeviceDisplayName: FLIR Blackfly S BFS-U3-200S6C
# DeviceAccessStatus: ReadWrite
# DeviceVersion: 1705.0.124.0
# DeviceDriverVersion: PGRUSBCam3.sys : 2.7.3.249
# DeviceUserID:
# DeviceIsUpdater: 0
# DeviceInstanceId: USB\VID_1E10&PID_4000&MI_00\6&356F58B8&0&0000
# DeviceCurrentSpeed: HighSpeed
# GUIXMLLocation: Device
# GUIXMLPath: Input.xml
# GenICamXMLLocation: Device
# GenICamXMLPath:
# DeviceU3VProtocol: 1
#
# *** CONFIGURING CHUNK DATA ***
#
# Chunk mode activated...
# Enabling entries...
# 	 Image: enabled
# 	 CRC: enabled
# 	 FrameID: enabled
# 	 OffsetX: enabled
# 	 OffsetY: enabled
# 	 Width: enabled
# 	 Height: enabled
# 	 ExposureTime: enabled
# 	 Gain: enabled
# 	 BlackLevel: enabled
# 	 PixelFormat: enabled
# 	 Timestamp: enabled
# 	 SequencerSetActive: enabled
# 	 SerialData: enabled
# 	 ExposureEndLineStatusAll: enabled
#
# *** IMAGE ACQUISTION ***
#
# Acquisition mode set to continuous...
# Acquiring images...
# Device serial number retrieved as 18474805...
# Grabbed Image 0, width = 2736, height = 1824
# Image saved at ChunkData-18474805-0.jpg
# Printing chunk data from nodemap...
# 	Chunk Mode Active: 1
# 	Chunk Selector: ExposureEndLineStatusAll
# 	Chunk Enable: 1
# 	Chunk Image: 1683907680
# 	Image CRC: 0x59a0145c
# 	Chunk Frame ID: 14
# 	Chunk Offset X: 1368
# 	Chunk Offset Y: 912
# 	Chunk Width: 2736
# 	Chunk Height: 1824
# 	Chunk Pixel Format: BayerRG8
# 	Chunk Exposure Time: 15004
# 	Chunk Gain Selector: All
# 	Chunk Gain: 6.2962
# 	Chunk Black Level Selector: All
# 	Chunk Black Level: 0
# 	Chunk Timestamp: 515822448288
# 	Chunk Sequencer Set Active: -1
# 	Chunk Exposure End Line Status All: 0xc
# 	Chunk Serial Data Length: 0
# 	Chunk Serial Data:
# 	Chunk Serial Receive Overflow: 0
#
# Grabbed Image 1, width = 2736, height = 1824
# Image saved at ChunkData-18474805-1.jpg
# Printing chunk data from nodemap...
# 	Chunk Mode Active: 1
# 	Chunk Selector: ExposureEndLineStatusAll
# 	Chunk Enable: 1
# 	Chunk Image: 1667261790
# 	Image CRC: 0x8a2451d4
# 	Chunk Frame ID: 15
# 	Chunk Offset X: 1368
# 	Chunk Offset Y: 912
# 	Chunk Width: 2736
# 	Chunk Height: 1824
# 	Chunk Pixel Format: BayerRG8
# 	Chunk Exposure Time: 15004
# 	Chunk Gain Selector: All
# 	Chunk Gain: 6.2962
# 	Chunk Black Level Selector: All
# 	Chunk Black Level: 0
# 	Chunk Timestamp: 516155781336
# 	Chunk Sequencer Set Active: -1
# 	Chunk Exposure End Line Status All: 0xc
# 	Chunk Serial Data Length: 0
# 	Chunk Serial Data:
# 	Chunk Serial Receive Overflow: 0
#
# Grabbed Image 2, width = 2736, height = 1824
# Image saved at ChunkData-18474805-2.jpg
# Printing chunk data from nodemap...
# 	Chunk Mode Active: 1
# 	Chunk Selector: ExposureEndLineStatusAll
# 	Chunk Enable: 1
# 	Chunk Image: 1465144916
# 	Image CRC: 0x9836ba6b
# 	Chunk Frame ID: 16
# 	Chunk Offset X: 1368
# 	Chunk Offset Y: 912
# 	Chunk Width: 2736
# 	Chunk Height: 1824
# 	Chunk Pixel Format: BayerRG8
# 	Chunk Exposure Time: 15004
# 	Chunk Gain Selector: All
# 	Chunk Gain: 4.68632
# 	Chunk Black Level Selector: All
# 	Chunk Black Level: 0
# 	Chunk Timestamp: 516489114896
# 	Chunk Sequencer Set Active: -1
# 	Chunk Exposure End Line Status All: 0xc
# 	Chunk Serial Data Length: 0
# 	Chunk Serial Data:
# 	Chunk Serial Receive Overflow: 0
#
# Grabbed Image 3, width = 2736, height = 1824
# Image saved at ChunkData-18474805-3.jpg
# Printing chunk data from nodemap...
# 	Chunk Mode Active: 1
# 	Chunk Selector: ExposureEndLineStatusAll
# 	Chunk Enable: 1
# 	Chunk Image: 1481988692
# 	Image CRC: 0x33c2ecea
# 	Chunk Frame ID: 17
# 	Chunk Offset X: 1368
# 	Chunk Offset Y: 912
# 	Chunk Width: 2736
# 	Chunk Height: 1824
# 	Chunk Pixel Format: BayerRG8
# 	Chunk Exposure Time: 15004
# 	Chunk Gain Selector: All
# 	Chunk Gain: 4.94502
# 	Chunk Black Level Selector: All
# 	Chunk Black Level: 0
# 	Chunk Timestamp: 516822448552
# 	Chunk Sequencer Set Active: -1
# 	Chunk Exposure End Line Status All: 0xc
# 	Chunk Serial Data Length: 0
# 	Chunk Serial Data:
# 	Chunk Serial Receive Overflow: 0
#
# Grabbed Image 4, width = 2736, height = 1824
# Image saved at ChunkData-18474805-4.jpg
# Printing chunk data from nodemap...
# 	Chunk Mode Active: 1
# 	Chunk Selector: ExposureEndLineStatusAll
# 	Chunk Enable: 1
# 	Chunk Image: 1482250582
# 	Image CRC: 0xdddd2980
# 	Chunk Frame ID: 18
# 	Chunk Offset X: 1368
# 	Chunk Offset Y: 912
# 	Chunk Width: 2736
# 	Chunk Height: 1824
# 	Chunk Pixel Format: BayerRG8
# 	Chunk Exposure Time: 15004
# 	Chunk Gain Selector: All
# 	Chunk Gain: 5.09605
# 	Chunk Black Level Selector: All
# 	Chunk Black Level: 0
# 	Chunk Timestamp: 517155781264
# 	Chunk Sequencer Set Active: -1
# 	Chunk Exposure End Line Status All: 0xc
# 	Chunk Serial Data Length: 0
# 	Chunk Serial Data:
# 	Chunk Serial Receive Overflow: 0
#
# Grabbed Image 5, width = 2736, height = 1824
# Image saved at ChunkData-18474805-5.jpg
# Printing chunk data from nodemap...
# 	Chunk Mode Active: 1
# 	Chunk Selector: ExposureEndLineStatusAll
# 	Chunk Enable: 1
# 	Chunk Image: 1532319574
# 	Image CRC: 0x492c1f77
# 	Chunk Frame ID: 19
# 	Chunk Offset X: 1368
# 	Chunk Offset Y: 912
# 	Chunk Width: 2736
# 	Chunk Height: 1824
# 	Chunk Pixel Format: BayerRG8
# 	Chunk Exposure Time: 15004
# 	Chunk Gain Selector: All
# 	Chunk Gain: 5.07327
# 	Chunk Black Level Selector: All
# 	Chunk Black Level: 0
# 	Chunk Timestamp: 517489114616
# 	Chunk Sequencer Set Active: -1
# 	Chunk Exposure End Line Status All: 0xc
# 	Chunk Serial Data Length: 0
# 	Chunk Serial Data:
# 	Chunk Serial Receive Overflow: 0
#
# Grabbed Image 6, width = 2736, height = 1824
# Image saved at ChunkData-18474805-6.jpg
# Printing chunk data from nodemap...
# 	Chunk Mode Active: 1
# 	Chunk Selector: ExposureEndLineStatusAll
# 	Chunk Enable: 1
# 	Chunk Image: 1515608147
# 	Image CRC: 0x9a24c3a4
# 	Chunk Frame ID: 20
# 	Chunk Offset X: 1368
# 	Chunk Offset Y: 912
# 	Chunk Width: 2736
# 	Chunk Height: 1824
# 	Chunk Pixel Format: BayerRG8
# 	Chunk Exposure Time: 15004
# 	Chunk Gain Selector: All
# 	Chunk Gain: 5.07327
# 	Chunk Black Level Selector: All
# 	Chunk Black Level: 0
# 	Chunk Timestamp: 517822447840
# 	Chunk Sequencer Set Active: -1
# 	Chunk Exposure End Line Status All: 0xc
# 	Chunk Serial Data Length: 0
# 	Chunk Serial Data:
# 	Chunk Serial Receive Overflow: 0
#
# Grabbed Image 7, width = 2736, height = 1824
# Image saved at ChunkData-18474805-7.jpg
# Printing chunk data from nodemap...
# 	Chunk Mode Active: 1
# 	Chunk Selector: ExposureEndLineStatusAll
# 	Chunk Enable: 1
# 	Chunk Image: 1515477588
# 	Image CRC: 0x95891b91
# 	Chunk Frame ID: 21
# 	Chunk Offset X: 1368
# 	Chunk Offset Y: 912
# 	Chunk Width: 2736
# 	Chunk Height: 1824
# 	Chunk Pixel Format: BayerRG8
# 	Chunk Exposure Time: 15004
# 	Chunk Gain Selector: All
# 	Chunk Gain: 5.08833
# 	Chunk Black Level Selector: All
# 	Chunk Black Level: 0
# 	Chunk Timestamp: 518155781480
# 	Chunk Sequencer Set Active: -1
# 	Chunk Exposure End Line Status All: 0xc
# 	Chunk Serial Data Length: 0
# 	Chunk Serial Data:
# 	Chunk Serial Receive Overflow: 0
#
# Grabbed Image 8, width = 2736, height = 1824
# Image saved at ChunkData-18474805-8.jpg
# Printing chunk data from nodemap...
# 	Chunk Mode Active: 1
# 	Chunk Selector: ExposureEndLineStatusAll
# 	Chunk Enable: 1
# 	Chunk Image: 1532320600
# 	Image CRC: 0xf572329f
# 	Chunk Frame ID: 22
# 	Chunk Offset X: 1368
# 	Chunk Offset Y: 912
# 	Chunk Width: 2736
# 	Chunk Height: 1824
# 	Chunk Pixel Format: BayerRG8
# 	Chunk Exposure Time: 15004
# 	Chunk Gain Selector: All
# 	Chunk Gain: 5.08833
# 	Chunk Black Level Selector: All
# 	Chunk Black Level: 0
# 	Chunk Timestamp: 518489114944
# 	Chunk Sequencer Set Active: -1
# 	Chunk Exposure End Line Status All: 0xc
# 	Chunk Serial Data Length: 0
# 	Chunk Serial Data:
# 	Chunk Serial Receive Overflow: 0
#
# Grabbed Image 9, width = 2736, height = 1824
# Image saved at ChunkData-18474805-9.jpg
# Printing chunk data from nodemap...
# 	Chunk Mode Active: 1
# 	Chunk Selector: ExposureEndLineStatusAll
# 	Chunk Enable: 1
# 	Chunk Image: 1515411284
# 	Image CRC: 0x522484fc
# 	Chunk Frame ID: 23
# 	Chunk Offset X: 1368
# 	Chunk Offset Y: 912
# 	Chunk Width: 2736
# 	Chunk Height: 1824
# 	Chunk Pixel Format: BayerRG8
# 	Chunk Exposure Time: 15004
# 	Chunk Gain Selector: All
# 	Chunk Gain: 5.08833
# 	Chunk Black Level Selector: All
# 	Chunk Black Level: 0
# 	Chunk Timestamp: 518822448064
# 	Chunk Sequencer Set Active: -1
# 	Chunk Exposure End Line Status All: 0xc
# 	Chunk Serial Data Length: 0
# 	Chunk Serial Data:
# 	Chunk Serial Receive Overflow: 0
#
# Disabling entries...
# 	 Image: not writable
# 	 CRC: not writable
# 	 FrameID: disabled
# 	 OffsetX: disabled
# 	 OffsetY: disabled
# 	 Width: disabled
# 	 Height: disabled
# 	 ExposureTime: disabled
# 	 Gain: disabled
# 	 BlackLevel: disabled
# 	 PixelFormat: disabled
# 	 Timestamp: disabled
# 	 SequencerSetActive: disabled
# 	 SerialData: disabled
# 	 ExposureEndLineStatusAll: disabled
# Chunk mode deactivated...
# Camera 0 example complete...
# Done! Press Enter to exit...

# %%
system = PySpin.System.GetInstance()
# Get camera list
cam_list = system.GetCameras()
num_cameras = cam_list.GetSize()

print('Number of cameras detected: %d' % num_cameras)
# Finish if there are no cameras
if num_cameras == 0:
    # Clear camera list before releasing system
    cam_list.Clear()

    # Release system instance
    system.ReleaseInstance()

    print('Not enough cameras!')
    input('Done! Press Enter to exit...')


cam = cam_list.GetByIndex(0)
cam.Init()
# Out:
# Number of cameras detected: 1

# %%
PySpin.RW
# Out:
# 4

# %%
cam.Gain.GetAccessMode()
# Out:
# 3

# %%
cam.TLDevice.DeviceSerialNumber.GetValue()
# Out:
# '18474805'

# %%
cam.AcquisitionFrameRateEnable()
# Out:
# True

# %%
cam.DeInit()

# %%
cam.AcquisitionFrameRate()
# Out:
# 3.0043462073974694

# %%
cam.GainAuto()
# Out:
# 2

# %%
# %run NodeMapInfo.py
# Out:
# Library version: 1.19.0.22
# Number of cameras detected: 1
# Running example for camera 0...
#
# *** PRINTING TRANSPORT LAYER DEVICE NODEMAP ***
#
# Root
#     Device Information
#         DeviceID: 18474805
#         Device Serial Number: 18474805
#         Device Vendor Name  : FLIR
#         Device Model Name: Blackfly S BFS-U3-200S6C
#         Device Type: U3V
#         Device Display Name: FLIR Blackfly S BFS-U3-200S6C
#         Device Access Status: ReadWrite
#         Device Version: 1705.0.124.0
#         Device Driver Version: PGRUSBCam3.sys : 2.7.3.249
#         Device User ID:
#         Device Is Updater Mode: False
#         DeviceInstanceId: USB\VID_1E10&PID_4000&MI_00\6&356F5...
#         Device Current Speed: HighSpeed
#         GUI XML Source: Device
#         GUI XML Path: Input.xml
#         GenICam XML Source: Device
#         GenICam XML Path:
#         Device Is In U3V Protocol: True
#
#     Device Control
#         Device Endianess Mechanism: Standard
#
#
# *** PRINTING TL STREAM NODEMAP ***
#
# Root
#     Stream Information
#         Stream ID  : 0
#         Stream Type: U3V
#         Total Buffer Count: 0
#
#     Buffer Handling Control
#         Manual Stream Buffer Count: 10
#         Resulting Stream Buffer Count: 10
#         Stream Buffer Count Max: 1513
#         Stream Buffer Count Mode: Auto
#         StreamDefaultBufferCount: 10
#         StreamDefaultBufferCountMax: 1513
#         StreamDefaultBufferCountMode: Auto
#         Stream Buffer Handling Mode: OldestFirst
#         CRC Check Enable: False
#         Stream Block Transfer Size: 4194304
#
#     Stream Diagnostics
#         Failed Buffer Count: 0
#         Buffer Underrun Count: 0
#
#
# *** PRINTING GENICAM NODEMAP ***
#
# Root
#     Acquisition Control
#         Acquisition Mode: Continuous
#         Acquisition Frame Count: 2
#         Acquisition Burst Frame Count: 1
#         Exposure Mode: Timed
#         Exposure Time: 14993.0
#         Exposure Auto: Continuous
#         Acquisition Frame Rate: 12.001655268294604
#         Resulting Frame Rate: 12.001655196284672
#         Acquisition Frame Rate Enable: False
#         Acquisition Line Rate: 87108.01341463414
#         Trigger Selector: FrameStart
#         Trigger Mode: Off
#         Trigger Source: Software
#         Trigger Overlap: Off
#         Trigger Delay: 208.0
#         Sensor Shutter Mode: Rolling
#
#     Analog Control
#         Gain Selector: All
#         Gain: 4.759448857005371
#         Gain Auto: Continuous
#         Black Level Selector: All
#         Black Level: 0.0
#         Balance Ratio Selector: Red
#         Balance Ratio: 1.393798828125
#         Balance White Auto: Continuous
#         Gamma: 0.800048828125
#         Gamma Enable: True
#
#     Image Format Control
#         Sensor Width: 5496
#         Sensor Height: 3672
#         Width Max: 5472
#         Height Max: 3648
#         Width: 2736
#         Height: 1824
#         Offset X: 1368
#         Offset Y: 912
#         Pixel Format: BayerRG8
#         Pixel Size: Bpp8
#         Pixel Color Filter: BayerRG
#         Pixel Dynamic Range Min: 0
#         Pixel Dynamic Range Max: 255
#         ISP Enable: False
#         Binning Selector: All
#         Binning Horizontal Mode: Sum
#         Binning Vertical Mode: Sum
#         Binning Horizontal: 1
#         Binning Vertical: 1
#         Decimation Selector: All
#         Decimation Horizontal Mode: Discard
#         Decimation Vertical Mode: Discard
#         Decimation Horizontal: 1
#         Decimation Vertical: 1
#         Reverse X: False
#         Reverse Y: False
#         Test Pattern Generator Selector: Sensor
#         Test Pattern: Off
#         ADC Bit Depth: Bit10
#
#     Device Control
#         Device Scan Type: Areascan
#         Device Vendor Name: FLIR
#         Device Model Name: Blackfly S BFS-U3-200S6C
#         Sensor Description: Sony IMX183 (1" Color CMOS)
#         Device Manufacturer Info: May 26 2017 09:11:02
#         Device Version: 1705.0.124.0
#         Device Firmware Version: 1705.0.124.0
#         Device Serial Number: 18474805
#         Device ID: 18474805
#         Device User ID:
#         Device TL Type: USB3Vision
#         Device Gen CP Version Major: 1
#         Device Gen CP Version Minor: 0
#         Device Max Throughput: 116608656
#         Device Link Speed: 60000000
#         Device Link Throughput Limit: 60000000
#         Device Link Bandwidth Reserve: 0.0
#         Device Link Current Throughput: 59894884
#         Device Indicator Mode: Active
#         Device Temperature Selector: Sensor
#         Device Temperature: 46.875
#         Timestamp Latch Value: 0
#         Timestamp Increment: 1000
#         Device Power Supply Selector: External
#         Power Supply Voltage: 4.5478515625
#         Power Supply Current: 0.349365234375
#         Device Uptime: 2377
#         Link Uptime: 2374
#         Enumeration Count: 1
#         Max Device Reset Time: 30000
#
#     Transport Layer Control
#         Payload Size: 4990464
#         TLParamsLocked: 0
#         USB3 Vision
#             Max Response Time: 200
#             Message Channel: 0
#             Access Privilege: 0
#             U3V Version Major: 1
#             U3V Version Minor: 0
#             U3V Capability: 0
#             U3V SIRM Available: True
#             U3V EIRM Available: True
#             U3V IIDC2 Available: False
#             Max Command Transfer Length: 512
#             Max Ack Transfer Length: 1024
#             Number of Stream Channels: 1
#             Current Speed: HighSpeed
#
#         Link Error Count: 0
#         Link Recovery Count: 0
#
#     Sequencer Control
#         Sequencer Mode: Off
#         Sequencer Configuration Mode: Off
#         Sequencer Configuration Valid: No
#         Sequencer Configuration Reset: Resets the sequencer configuration ...
#         Sequencer Feature Selector: Gain
#         Sequencer Feature Enable: True
#         Sequencer Set Start: 0
#         Sequencer Set Selector: 0
#         Sequencer Set Valid: No
#         Sequencer Set Save: Saves the current device configurat...
#         Sequencer Set Load: Loads currently selected sequencer ...
#         Sequencer Path Selector: 0
#         Sequencer Trigger Source: Off
#
#     Color Transformation Control
#         RGB Transform Light Source: General
#
#     Auto Algorithm Control
#         ROI Selector: Awb
#         ROI Enable: False
#         White Balance Auto Profile: Indoor
#         White Balance Auto Lower Limit: 0.5
#         White Balance Auto Upper Limit: 4.0
#         White Balance Auto Damping: 0.25
#         Target Grey Value Auto: Continuous
#         Lighting Mode: Normal
#         Metering Mode: Average
#         Exposure Time Lower Limit: 100.0
#         Exposure Time Upper Limit: 15000.0
#         Gain Lower Limit: 0.0
#         Gain Upper Limit: 18.000065071923338
#         Target Grey Value Lower Limit: 3.9100684261974585
#         Target Grey Value Upper Limit: 93.841642228739
#         EV Compensation: 0.0
#         Auto Exposure Damping: 0.5
#         Auto Exposure Control Priority: Gain
#
#     Flat Field Correction Control
#         Flat Field User Table Control
#
#
#     Defective Pixel Correction
#         Defect Correct Static Enable: True
#         Defect Correction Mode: Average
#         Defect Table Pixel Count: 0
#         Defect Table Apply: Applies the current defect table, s...
#         Defect Table Factory Restore: Restores the factory default eeprom...
#
#     User Set Control
#         User Set Selector: Default
#         User Set Load: Loads the User Set specified by Use...
#         User Set Save: Saves the User Set specified by Use...
#         User Set Default: Default
#         User Set Feature Selector: AasRoiEnableAe
#         User Set Feature Enable: True
#
#     Chunk Data Control
#         Chunk Mode Active: False
#         Chunk Selector: FrameID
#         Chunk Enable: False
#         Chunk Gain Selector: All
#         Chunk Black Level Selector: All
#
#     LUT Control
#         LUT Selector: LUT1
#         LUT Enable: False
#         LUT Index: 0
#         LUT Value: 0
#
#     Event Control
#         Event Selector: Error
#         Event Notification: Off
#         Event Exposure End Data
#             Event Exposure End: 40003
#
#         Event Error Data
#             Event Error: 40000
#
#         Event Serial Port Receive Data
#             Event Serial Port Receive: 40005
#
#         Event Test Data
#             Event Test: 20479
#
#
#     Counter And Timer Control
#         Counter Selector: Counter0
#         Counter Event Source: MHzTick
#         Counter Duration: 1
#         Counter Value: 1
#         Counter Trigger Source: ExposureStart
#         Counter Trigger Activation: RisingEdge
#         Counter Status: CounterTriggerWait
#         Counter Delay: 0
#
#     Test Control
#         Test Pending Ack: 0
#         Test 0001: 0
#         GUI XML Manifest Address: 4026535968
#
#     Logic Block Control
#         Logic Block Selector: LogicBlock0
#         Logic Block LUT Selector: Value
#         Logic Block LUT Input Selector: Input0
#         Logic Block LUT Input Source: Zero
#         Logic Block LUT Input Activation: LevelHigh
#         Logic Block LUT Output Value All: 255
#         Logic Block LUT Row Index: 0
#         Logic Block LUT Output Value: True
#
#     Digital IO Control
#         Line Selector: Line0
#         Line Mode: Input
#         Line Inverter: False
#         Line Status: False
#         Line Status All: 12
#         Input filter Selector: Deglitch
#         Line Filter Width: 0.0
#         Line Source: Off
#         Line Format: OptoCoupled
#         User Output Selector: UserOutput0
#         User Output Value: False
#         User Output Value All: 0
#
#     Serial Port Control
#         Serial Port Selector: SerialPort0
#         Serial Port Source: Off
#         Serial Port Baud Rate: Baud57600
#         Serial Port Data Bits: 8
#         Serial Port Stop Bits: Bits1
#         Serial Port Parity: None
#         Transmit Queue Max Character Count: 4096
#         Transmit Queue Current Character Count: 0
#         Receive Queue Max Character Count: 4096
#         Receive Queue Current Character Count: 0
#         Receive Framing Error Count: 0
#         Receive Parity Error Count: 0
#
#     File Access
#         File Selector: UserSetDefault
#         File Operation Selector: Open
#         File Open Mode: Read
#         File Access Offset: 0
#         File Access Length: 1
#         File Operation Status: Success
#         File Operation Result: 0
#         File Size: 1360
#
#     Transfer Control
#         Transfer Control Mode: Basic
#         Transfer Queue Max Block Count: 2
#         Transfer Queue Current Block Count: 0
#         Transfer Queue Overflow Count: 1390
#
#
# Camera 0 example complete...
# Done! Press Enter to exit...

# %%
# %run Examples\\Python3\\Enumeration.py
# Out:
# Library version: 1.19.0.22
# Number of interfaces detected: 4
# Number of cameras detected: 1
#
# *** QUERYING INTERFACES ***
#
# GEV Interface 0
# 	No devices detected.
#
# USB Interface 0
# 	No devices detected.
#
# USB Interface 1
# 	No devices detected.
#
# USB Interface 2
# 	Device 0 FLIR Blackfly S BFS-U3-200S6C
# Done! Press Enter to exit...

# %%
#ACQUISITION EXAMPLE
# coding=utf-8
# =============================================================================
#  Copyright © 2017 FLIR Integrated Imaging Solutions, Inc. All Rights Reserved.
#
#  This software is the confidential and proprietary information of FLIR
#  Integrated Imaging Solutions, Inc. ("Confidential Information"). You
#  shall not disclose such Confidential Information and shall use it only in
#  accordance with the terms of the license agreement you entered into
#  with FLIR Integrated Imaging Solutions, Inc. (FLIR).
#
#  FLIR MAKES NO REPRESENTATIONS OR WARRANTIES ABOUT THE SUITABILITY OF THE
#  SOFTWARE, EITHER EXPRESSED OR IMPLIED, INCLUDING, BUT NOT LIMITED TO, THE
#  IMPLIED WARRANTIES OF MERCHANTABILITY, FITNESS FOR A PARTICULAR
#  PURPOSE, OR NON-INFRINGEMENT. FLIR SHALL NOT BE LIABLE FOR ANY DAMAGES
#  SUFFERED BY LICENSEE AS A RESULT OF USING, MODIFYING OR DISTRIBUTING
#  THIS SOFTWARE OR ITS DERIVATIVES.
# =============================================================================
#
# Acquisition.py shows how to acquire images. It relies on
# information provided in the Enumeration example. Also, check out the
# ExceptionHandling and NodeMapInfo examples if you haven't already.
# ExceptionHandling shows the handling of standard and Spinnaker exceptions
# while NodeMapInfo explores retrieving information from various node types.
#
# This example touches on the preparation and cleanup of a camera just before
# and just after the acquisition of images. Image retrieval and conversion,
# grabbing image data, and saving images are all covered as well.
#
# Once comfortable with Acquisition, we suggest checking out
# AcquisitionMultipleCamera, NodeMapCallback, or SaveToAvi.
# AcquisitionMultipleCamera demonstrates simultaneously acquiring images from
# a number of cameras, NodeMapCallback serves as a good introduction to
# programming with callbacks and events, and SaveToAvi exhibits video creation.

import os
import PySpin

NUM_IMAGES = 10  # number of images to grab


def acquire_images(cam, nodemap, nodemap_tldevice):
    """
    This function acquires and saves 10 images from a device.

    :param cam: Camera to acquire images from.
    :param nodemap: Device nodemap.
    :param nodemap_tldevice: Transport layer device nodemap.
    :type cam: CameraPtr
    :type nodemap: INodeMap
    :type nodemap_tldevice: INodeMap
    :return: True if successful, False otherwise.
    :rtype: bool
    """

    print('*** IMAGE ACQUISITION ***\n')
    try:
        result = True

        # Set acquisition mode to continuous
        #
        #  *** NOTES ***
        #  Because the example acquires and saves 10 images, setting acquisition
        #  mode to continuous lets the example finish. If set to single frame
        #  or multiframe (at a lower number of images), the example would just
        #  hang. This would happen because the example has been written to
        #  acquire 10 images while the camera would have been programmed to
        #  retrieve less than that.
        #
        #  Setting the value of an enumeration node is slightly more complicated
        #  than other node types. Two nodes must be retrieved: first, the
        #  enumeration node is retrieved from the nodemap; and second, the entry
        #  node is retrieved from the enumeration node. The integer value of the
        #  entry node is then set as the new value of the enumeration node.
        #
        #  Notice that both the enumeration and the entry nodes are checked for
        #  availability and readability/writability. Enumeration nodes are
        #  generally readable and writable whereas their entry nodes are only
        #  ever readable.
        #
        #  Retrieve enumeration node from nodemap

        # In order to access the node entries, they have to be casted to a pointer type (CEnumerationPtr here)
        node_acquisition_mode = PySpin.CEnumerationPtr(nodemap.GetNode('AcquisitionMode'))
        if not PySpin.IsAvailable(node_acquisition_mode) or not PySpin.IsWritable(node_acquisition_mode):
            print('Unable to set acquisition mode to continuous (enum retrieval). Aborting...')
            return False

        # Retrieve entry node from enumeration node
        node_acquisition_mode_continuous = node_acquisition_mode.GetEntryByName('Continuous')
        if not PySpin.IsAvailable(node_acquisition_mode_continuous) or not PySpin.IsReadable(node_acquisition_mode_continuous):
            print('Unable to set acquisition mode to continuous (entry retrieval). Aborting...')
            return False

        # Retrieve integer value from entry node
        acquisition_mode_continuous = node_acquisition_mode_continuous.GetValue()

        # Set integer value from entry node as new value of enumeration node
        node_acquisition_mode.SetIntValue(acquisition_mode_continuous)

        print('Acquisition mode set to continuous...')

        #  Begin acquiring images
        #
        #  *** NOTES ***
        #  What happens when the camera begins acquiring images depends on the
        #  acquisition mode. Single frame captures only a single image, multi
        #  frame catures a set number of images, and continuous captures a
        #  continuous stream of images. Because the example calls for the
        #  retrieval of 10 images, continuous mode has been set.
        #
        #  *** LATER ***
        #  Image acquisition must be ended when no more images are needed.
        cam.BeginAcquisition()

        print('Acquiring images...')

        #  Retrieve device serial number for filename
        #
        #  *** NOTES ***
        #  The device serial number is retrieved in order to keep cameras from
        #  overwriting one another. Grabbing image IDs could also accomplish
        #  this.
        device_serial_number = ''
        node_device_serial_number = PySpin.CStringPtr(nodemap_tldevice.GetNode('DeviceSerialNumber'))
        if PySpin.IsAvailable(node_device_serial_number) and PySpin.IsReadable(node_device_serial_number):
            device_serial_number = node_device_serial_number.GetValue()
            print('Device serial number retrieved as %s...' % device_serial_number)

        # Retrieve, convert, and save images
        for i in range(NUM_IMAGES):
            try:

                #  Retrieve next received image
                #
                #  *** NOTES ***
                #  Capturing an image houses images on the camera buffer. Trying
                #  to capture an image that does not exist will hang the camera.
                #
                #  *** LATER ***
                #  Once an image from the buffer is saved and/or no longer
                #  needed, the image must be released in order to keep the
                #  buffer from filling up.
                image_result = cam.GetNextImage()

                #  Ensure image completion
                #
                #  *** NOTES ***
                #  Images can easily be checked for completion. This should be
                #  done whenever a complete image is expected or required.
                #  Further, check image status for a little more insight into
                #  why an image is incomplete.
                if image_result.IsIncomplete():
                    print('Image incomplete with image status %d ...' % image_result.GetImageStatus())

                else:

                    #  Print image information; height and width recorded in pixels
                    #
                    #  *** NOTES ***
                    #  Images have quite a bit of available metadata including
                    #  things such as CRC, image status, and offset values, to
                    #  name a few.
                    width = image_result.GetWidth()
                    height = image_result.GetHeight()
                    print('Grabbed Image %d, width = %d, height = %d' % (i, width, height))

                    #  Convert image to mono 8
                    #
                    #  *** NOTES ***
                    #  Images can be converted between pixel formats by using
                    #  the appropriate enumeration value. Unlike the original
                    #  image, the converted one does not need to be released as
                    #  it does not affect the camera buffer.
                    #
                    #  When converting images, color processing algorithm is an
                    #  optional parameter.
                    image_converted = image_result.Convert(PySpin.PixelFormat_Mono8, PySpin.HQ_LINEAR)

                    # Create a unique filename
                    if device_serial_number:
                        filename = 'Acquisition-%s-%d.jpg' % (device_serial_number, i)
                    else:  # if serial number is empty
                        filename = 'Acquisition-%d.jpg' % i

                    #  Save image
                    #
                    #  *** NOTES ***
                    #  The standard practice of the examples is to use device
                    #  serial numbers to keep images of one device from
                    #  overwriting those of another.
                    image_converted.Save(filename)
                    print('Image saved at %s' % filename)

                    #  Release image
                    #
                    #  *** NOTES ***
                    #  Images retrieved directly from the camera (i.e. non-converted
                    #  images) need to be released in order to keep from filling the
                    #  buffer.
                    image_result.Release()
                    print('')

            except PySpin.SpinnakerException as ex:
                print('Error: %s' % ex)
                return False

        #  End acquisition
        #
        #  *** NOTES ***
        #  Ending acquisition appropriately helps ensure that devices clean up
        #  properly and do not need to be power-cycled to maintain integrity.
        cam.EndAcquisition()
    
    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return False

    return result


def print_device_info(nodemap):
    """
    This function prints the device information of the camera from the transport
    layer; please see NodeMapInfo example for more in-depth comments on printing
    device information from the nodemap.

    :param nodemap: Transport layer device nodemap.
    :type nodemap: INodeMap
    :returns: True if successful, False otherwise.
    :rtype: bool
    """

    print('*** DEVICE INFORMATION ***\n')

    try:
        result = True
        node_device_information = PySpin.CCategoryPtr(nodemap.GetNode('DeviceInformation'))

        if PySpin.IsAvailable(node_device_information) and PySpin.IsReadable(node_device_information):
            features = node_device_information.GetFeatures()
            for feature in features:
                node_feature = PySpin.CValuePtr(feature)
                print('%s: %s' % (node_feature.GetName(),
                                  node_feature.ToString() if PySpin.IsReadable(node_feature) else 'Node not readable'))

        else:
            print('Device control information not available.')

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return False

    return result


def run_single_camera(cam):
    """
    This function acts as the body of the example; please see NodeMapInfo example
    for more in-depth comments on setting up cameras.

    :param cam: Camera to run on.
    :type cam: CameraPtr
    :return: True if successful, False otherwise.
    :rtype: bool
    """
    try:
        result = True

        # Retrieve TL device nodemap and print device information
        nodemap_tldevice = cam.GetTLDeviceNodeMap()

        result &= print_device_info(nodemap_tldevice)

        # Initialize camera
        cam.Init()

        # Retrieve GenICam nodemap
        nodemap = cam.GetNodeMap()

        # Acquire images
        result &= acquire_images(cam, nodemap, nodemap_tldevice)

        # Deinitialize camera
        cam.DeInit()

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        result = False

    return result


def main():
    """
    Example entry point; please see Enumeration example for more in-depth
    comments on preparing and cleaning up the system.

    :return: True if successful, False otherwise.
    :rtype: bool
    """

    # Since this application saves images in the current folder
    # we must ensure that we have permission to write to this folder.
    # If we do not have permission, fail right away.
    try:
        test_file = open('test.txt', 'w+')
    except IOError:
        print('Unable to write to current directory. Please check permissions.')
        input('Press Enter to exit...')
        return False

    test_file.close()
    os.remove(test_file.name)

    result = True

    # Retrieve singleton reference to system object
    system = PySpin.System.GetInstance()

    # Get current library version
    version = system.GetLibraryVersion()
    print('Library version: %d.%d.%d.%d' % (version.major, version.minor, version.type, version.build))

    # Retrieve list of cameras from the system
    cam_list = system.GetCameras()

    num_cameras = cam_list.GetSize()

    print('Number of cameras detected: %d' % num_cameras)

    # Finish if there are no cameras
    if num_cameras == 0:

        # Clear camera list before releasing system
        cam_list.Clear()

        # Release system instance
        system.ReleaseInstance()

        print('Not enough cameras!')
        input('Done! Press Enter to exit...')
        return False

    # Run example on each camera
    for i, cam in enumerate(cam_list):

        print('Running example for camera %d...' % i)

        result &= run_single_camera(cam)
        print('Camera %d example complete... \n' % i)

    # Release reference to camera
    # NOTE: Unlike the C++ examples, we cannot rely on pointer objects being automatically
    # cleaned up when going out of scope.
    # The usage of del is preferred to assigning the variable to None.
    del cam

    # Clear camera list before releasing system
    cam_list.Clear()

    # Release system instance
    system.ReleaseInstance()

    input('Done! Press Enter to exit...')
    return result

if __name__ == '__main__':
    main()
# Out:
# Library version: 1.19.0.22
# Number of cameras detected: 1
# Running example for camera 0...
# *** DEVICE INFORMATION ***
#
# DeviceID: 18474805
# DeviceSerialNumber: 18474805
# DeviceVendorName: FLIR
# DeviceModelName: Blackfly S BFS-U3-200S6C
# DeviceType: U3V
# DeviceDisplayName: FLIR Blackfly S BFS-U3-200S6C
# DeviceAccessStatus: ReadWrite
# DeviceVersion: 1705.0.124.0
# DeviceDriverVersion: PGRUSBCam3.sys : 2.7.3.249
# DeviceUserID:
# DeviceIsUpdater: 0
# DeviceInstanceId: USB\VID_1E10&PID_4000&MI_00\6&356F58B8&0&0000
# DeviceCurrentSpeed: HighSpeed
# GUIXMLLocation: Device
# GUIXMLPath: Input.xml
# GenICamXMLLocation: Device
# GenICamXMLPath:
# DeviceU3VProtocol: 1
# *** IMAGE ACQUISITION ***
#
# Acquisition mode set to continuous...
# Acquiring images...
# Device serial number retrieved as 18474805...
# Grabbed Image 0, width = 5472, height = 3648
# Image saved at Acquisition-18474805-0.jpg
#
# Grabbed Image 1, width = 5472, height = 3648
# Image saved at Acquisition-18474805-1.jpg
#
# Grabbed Image 2, width = 5472, height = 3648
# Image saved at Acquisition-18474805-2.jpg
#
# Grabbed Image 3, width = 5472, height = 3648
# Image saved at Acquisition-18474805-3.jpg
#
# Grabbed Image 4, width = 5472, height = 3648
# Image saved at Acquisition-18474805-4.jpg
#
# Grabbed Image 5, width = 5472, height = 3648
# Image saved at Acquisition-18474805-5.jpg
#
# Grabbed Image 6, width = 5472, height = 3648
# Image saved at Acquisition-18474805-6.jpg
#
# Grabbed Image 7, width = 5472, height = 3648
# Image saved at Acquisition-18474805-7.jpg
#
# Grabbed Image 8, width = 5472, height = 3648
# Image saved at Acquisition-18474805-8.jpg
#
# Grabbed Image 9, width = 5472, height = 3648
# Image saved at Acquisition-18474805-9.jpg
#
# Camera 0 example complete...
# Done! Press Enter to exit...

# %%
# %run ImageFormatControl.py
# Out:
# Library version: 1.19.0.22
# Number of cameras detected: 1
# Running example for camera 0...
# *** DEVICE INFORMATION ***
#
# DeviceID: 18474805
# DeviceSerialNumber: 18474805
# DeviceVendorName: FLIR
# DeviceModelName: Blackfly S BFS-U3-200S6C
# DeviceType: U3V
# DeviceDisplayName: FLIR Blackfly S BFS-U3-200S6C
# DeviceAccessStatus: ReadWrite
# DeviceVersion: 1705.0.124.0
# DeviceDriverVersion: PGRUSBCam3.sys : 2.7.3.249
# DeviceUserID:
# DeviceIsUpdater: 0
# DeviceInstanceId: USB\VID_1E10&PID_4000&MI_00\6&356F58B8&0&0000
# DeviceCurrentSpeed: HighSpeed
# GUIXMLLocation: Device
# GUIXMLPath: Input.xml
# GenICamXMLLocation: Device
# GenICamXMLPath:
# DeviceU3VProtocol: 1
#
# *** CONFIGURING CUSTOM IMAGE SETTINGS ***
#
# Pixel format set to Mono8...
# Height set to 1824...
# Error: Spinnaker: GenICam::OutOfRangeException= Value = 1368 must be equal or smaller than Max = 0. : OutOfRangeException thrown in node 'OffsetX' while calling 'OffsetX.SetValue()' (file 'IntegerT.h', line 79) [-2002]
# Camera 0 example complete...
# Done! Press Enter to exit...

# %%
# %run CounterAndTimer.py
# Out:
# Library version: 1.19.0.22
# Number of cameras detected: 1
# Running example for camera 0...
# *** DEVICE INFORMATION ***
#
# DeviceID: 18474805
# DeviceSerialNumber: 18474805
# DeviceVendorName: FLIR
# DeviceModelName: Blackfly S BFS-U3-200S6C
# DeviceType: U3V
# DeviceDisplayName: FLIR Blackfly S BFS-U3-200S6C
# DeviceAccessStatus: ReadWrite
# DeviceVersion: 1705.0.124.0
# DeviceDriverVersion: PGRUSBCam3.sys : 2.7.3.249
# DeviceUserID:
# DeviceIsUpdater: 0
# DeviceInstanceId: USB\VID_1E10&PID_4000&MI_00\6&356F58B8&0&0000
# DeviceCurrentSpeed: HighSpeed
# GUIXMLLocation: Device
# GUIXMLPath: Input.xml
# GenICamXMLLocation: Device
# GenICamXMLPath:
# DeviceU3VProtocol: 1
#
# Configuring Pulse Width Modulation signal
#
# The duty cycle has been set to 90.4%
#
# The pulse rate has been set to 16.0 Hz
#
# Configuring GPIO strobe output
#
# Configuring Exposure and Trigger
#
# *** IMAGE ACQUISITION ***
#
# Acquisition mode set to continuous...
# Acquiring images...
# Device serial number retrieved as 18474805...
#
# Grabbed image 0, width = 5472, height = 3648
# Image saved at CounterAndTimer-18474805-0.jpg
#
# Grabbed image 1, width = 5472, height = 3648
# Image saved at CounterAndTimer-18474805-1.jpg
#
# Grabbed image 2, width = 5472, height = 3648
# Image saved at CounterAndTimer-18474805-2.jpg
#
# Grabbed image 3, width = 5472, height = 3648
# Image saved at CounterAndTimer-18474805-3.jpg
#
# Grabbed image 4, width = 5472, height = 3648
# Image saved at CounterAndTimer-18474805-4.jpg
#
# Grabbed image 5, width = 5472, height = 3648
# Image saved at CounterAndTimer-18474805-5.jpg
#
# Grabbed image 6, width = 5472, height = 3648
# Image saved at CounterAndTimer-18474805-6.jpg
#
# Grabbed image 7, width = 5472, height = 3648
# Image saved at CounterAndTimer-18474805-7.jpg
#
# Grabbed image 8, width = 5472, height = 3648
# Image saved at CounterAndTimer-18474805-8.jpg
#
# Grabbed image 9, width = 5472, height = 3648
# Image saved at CounterAndTimer-18474805-9.jpg
#
# Camera 0 example complete...
# Done! Press Enter to exit...
